# %% [markdown]
# # Diet and Health Analysis Project
#
# ## Notebook 1: Data Cleaning
#
# ### Cleaned all the datasets

# %%
import pandas as pd
import numpy as np

# %%
food = pd.read_csv(
    r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\raw\food_consumption.csv",
    header=1)
gdp = pd.read_csv(
    r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\raw\gdp.csv",
    skiprows=4)
life = pd.read_csv(
    r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\raw\life_expectancy.csv",
    skiprows=4)
diabetes = pd.read_csv(
    r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\raw\diabetes.csv",
    skiprows=4)
obesity = pd.read_csv(
    r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\raw\obesity.csv")

# %%
food.head()
# Out:
#     Unnamed: 0                           Unnamed: 1               Unnamed: 2  \
# 0  Afghanistan  Food supply quantity (kg/capita/yr)                     Eggs
# 1  Afghanistan  Food supply quantity (kg/capita/yr)            Fish, Seafood
# 2  Afghanistan  Food supply quantity (kg/capita/yr)  Fruits - Excluding Wine
# 3  Afghanistan  Food supply quantity (kg/capita/yr)                     Meat
# 4  Afghanistan  Food supply quantity (kg/capita/yr)  Milk - Excluding Butter
#
#      Unit  Value
# 0  kg/cap   0.58
# 1  kg/cap   0.38
# 2  kg/cap  39.92
# 3  kg/cap   6.39
# 4  kg/cap  37.11

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1241 entries, 0 to 1240
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1239 non-null   object
#  1   Unnamed: 1  1239 non-null   object
#  2   Unnamed: 2  1239 non-null   object
#  3   Unit        1239 non-null   object
#  4   Value       1239 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 48.6+ KB

# %%
food.shape
# Out:
# (1241, 5)

# %%
food.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unit', 'Value'], dtype='object')

# %%
food.columns = ["Country", "Element", "Food_Category", "Unit", "Value"]

# %%
food.head()
# Out:
#        Country                              Element            Food_Category  \
# 0  Afghanistan  Food supply quantity (kg/capita/yr)                     Eggs
# 1  Afghanistan  Food supply quantity (kg/capita/yr)            Fish, Seafood
# 2  Afghanistan  Food supply quantity (kg/capita/yr)  Fruits - Excluding Wine
# 3  Afghanistan  Food supply quantity (kg/capita/yr)                     Meat
# 4  Afghanistan  Food supply quantity (kg/capita/yr)  Milk - Excluding Butter
#
#      Unit  Value
# 0  kg/cap   0.58
# 1  kg/cap   0.38
# 2  kg/cap  39.92
# 3  kg/cap   6.39
# 4  kg/cap  37.11

# %%
food.isnull().sum()
# Out:
# Country          2
# Element          2
# Food_Category    2
# Unit             2
# Value            2
# dtype: int64

# %%
food[food.isnull().any(axis=1)]
# Out:
#      Country Element Food_Category Unit  Value
# 1239     NaN     NaN           NaN  NaN    NaN
# 1240     NaN     NaN           NaN  NaN    NaN

# %%
food = food.dropna(how="all")

# %%
food.shape
# Out:
# (1239, 5)

# %%
food.isnull().sum()
# Out:
# Country          0
# Element          0
# Food_Category    0
# Unit             0
# Value            0
# dtype: int64

# %%
food.duplicated().sum()
# Out:
# 0

# %%
food.to_csv(r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\processed\food_clean.csv", index=False)

# %%
gdp.head()
# Out:
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  GDP per capita (current US$)
# 1  Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                  Afghanistan          AFG  GDP per capita (current US$)
# 3   Africa Western and Central          AFW  GDP per capita (current US$)
# 4                       Angola          AGO  GDP per capita (current US$)
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
# 1  NY.GDP.PCAP.CD  186.089204  186.909053  197.367547  225.400079  208.962717
# 2  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
# 3  NY.GDP.PCAP.CD  121.936832  127.451040  133.823783  139.004980  148.545883
# 4  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 71 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            151 non-null    float64
#  5   1961            154 non-null    float64
#  6   1962            156 non-null    float64
#  7   1963            156 non-null    float64
#  8   1964            156 non-null    float64
#  9   1965            162 non-null    float64
#  10  1966            163 non-null    float64
#  11  1967            167 non-null    float64
#  12  1968            168 non-null    float64
#  13  1969            168 non-null    float64
#  14  1970            190 non-null    float64
#  15  1971            191 non-null    float64
#  16  1972            191 non-null    float64
# ...

# %%
gdp.shape
# Out:
# (266, 71)

# %%
gdp.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', '2025', 'Unnamed: 70'],
#       dtype='object')

# %%
gdp_clean = gdp[["Country Name", "Country Code", "2023"]]

# %%
gdp_clean.columns = ["Country", "Country_Code", "GDP_per_Capita"]

# %%
gdp_clean.head()
# Out:
#                        Country Country_Code  GDP_per_Capita
# 0                        Aruba          ABW    35718.753119
# 1  Africa Eastern and Southern          AFE     1571.449189
# 2                  Afghanistan          AFG      413.757895
# 3   Africa Western and Central          AFW     1841.855064
# 4                       Angola          AGO     2916.136633

# %%
gdp_clean.isnull().sum()
# Out:
# Country            0
# Country_Code       0
# GDP_per_Capita    15
# dtype: int64

# %%
gdp_clean[gdp_clean.isnull().any(axis=1)]
# Out:
#                        Country Country_Code  GDP_per_Capita
# 11              American Samoa          ASM             NaN
# 50                        Cuba          CUB             NaN
# 69                     Eritrea          ERI             NaN
# 84                   Gibraltar          GIB             NaN
# 93                        Guam          GUM             NaN
# 108                Isle of Man          IMN             NaN
# 110             Not classified          INX             NaN
# 147   St. Martin (French part)          MAF             NaN
# 164   Northern Mariana Islands          MNP             NaN
# 193  Korea, Dem. People's Rep.          PRK             NaN
# 216                South Sudan          SSD             NaN
# 227       Syrian Arab Republic          SYR             NaN
# 255     British Virgin Islands          VGB             NaN
# 256      Virgin Islands (U.S.)          VIR             NaN
# 262                Yemen, Rep.          YEM             NaN

# %%
gdp_clean.duplicated().sum()
# Out:
# 0

# %%
gdp_clean.to_csv(r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\processed\gdp_clean.csv", index=False)

# %%
life.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                             Indicator Name  Indicator Code       1960  \
# 0  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  64.049000
# 1  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  44.169658
# 2  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  32.799000
# 3  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  37.779636
# 4  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  37.933000
#
#         1961       1962       1963       1964       1965  ...       2017  \
# 0  64.215000  64.602000  64.944000  65.303000  65.615000  ...  75.620000
# 1  44.468838  44.877890  45.160583  45.535695  45.770723  ...  62.591275
# ...

# %%
life.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 71 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            263 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            263 non-null    float64
#  8   1964            263 non-null    float64
#  9   1965            263 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
life.shape
# Out:
# (266, 71)

# %%
life.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', '2025', 'Unnamed: 70'],
#       dtype='object')

# %%
life_clean = life[["Country Name", "Country Code", "2023"]]

# %%
life_clean.columns = ["Country", "Country_Code", "Life_Expectancy"]

# %%
life_clean.head()
# Out:
#                        Country Country_Code  Life_Expectancy
# 0                        Aruba          ABW        76.353000
# 1  Africa Eastern and Southern          AFE        65.146228
# 2                  Afghanistan          AFG        66.035000
# 3   Africa Western and Central          AFW        58.855740
# 4                       Angola          AGO        64.617000

# %%
life_clean.isnull().sum()
# Out:
# Country            0
# Country_Code       0
# Life_Expectancy    1
# dtype: int64

# %%
life_clean[life_clean.isnull().any(axis=1)]
# Out:
#             Country Country_Code  Life_Expectancy
# 110  Not classified          INX              NaN

# %%
life_clean = life_clean.dropna(subset=["Life_Expectancy"])

# %%
life_clean.duplicated().sum()
# Out:
# 0

# %%
life_clean.isnull().sum()
# Out:
# Country            0
# Country_Code       0
# Life_Expectancy    0
# dtype: int64

# %%
life_clean.to_csv(r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\processed\life_expectancy_clean.csv", index=False)

# %%
diabetes.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS   NaN
# 1  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS   NaN
# 2  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS   NaN
# 3  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS   NaN
# 4  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...  2017  2018  2019  2020  2021  2022  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 71 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            0 non-null      float64
#  5   1961            0 non-null      float64
#  6   1962            0 non-null      float64
#  7   1963            0 non-null      float64
#  8   1964            0 non-null      float64
#  9   1965            0 non-null      float64
#  10  1966            0 non-null      float64
#  11  1967            0 non-null      float64
#  12  1968            0 non-null      float64
#  13  1969            0 non-null      float64
#  14  1970            0 non-null      float64
#  15  1971            0 non-null      float64
#  16  1972            0 non-null      float64
# ...

# %%
diabetes.shape
# Out:
# (266, 71)

# %%
diabetes.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', '2025', 'Unnamed: 70'],
#       dtype='object')

# %%
diabetes_clean = diabetes[["Country Name", "Country Code", "2024"]]

# %%
diabetes_clean.columns = ["Country", "Country_Code", "Diabetes_Prevalence"]

# %%
diabetes_clean.head()
# Out:
#                        Country Country_Code  Diabetes_Prevalence
# 0                        Aruba          ABW             4.600000
# 1  Africa Eastern and Southern          AFE             6.454044
# 2                  Afghanistan          AFG            11.700000
# 3   Africa Western and Central          AFW             4.219277
# 4                       Angola          AGO             4.900000

# %%
diabetes_clean.isnull().sum()
# Out:
# Country                0
# Country_Code           0
# Diabetes_Prevalence    9
# dtype: int64

# %%
diabetes_clean[diabetes_clean.isnull().any(axis=1)]
# Out:
#                        Country Country_Code  Diabetes_Prevalence
# 11              American Samoa          ASM                  NaN
# 38             Channel Islands          CHI                  NaN
# 84                   Gibraltar          GIB                  NaN
# 110             Not classified          INX                  NaN
# 147   St. Martin (French part)          MAF                  NaN
# 164   Northern Mariana Islands          MNP                  NaN
# 225  Sint Maarten (Dutch part)          SXM                  NaN
# 228   Turks and Caicos Islands          TCA                  NaN
# 255     British Virgin Islands          VGB                  NaN

# %%
diabetes_clean.duplicated().sum()
# Out:
# 0

# %%
diabetes_clean = diabetes_clean.dropna(subset=["Diabetes_Prevalence"])

# %%
diabetes_clean.isnull().sum()
# Out:
# Country                0
# Country_Code           0
# Diabetes_Prevalence    0
# dtype: int64

# %%
diabetes_clean.to_csv(r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\processed\diabetes_clean.csv", index=False)

# %%
obesity.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  2023
# 1      Albania  ALB  2023
# 2      Algeria  DZA  2023
# 3      Andorra  AND  2023
# 4       Angola  AGO  2023
#
#    Obesity among adults, BMI >= 30 kg/m2 (crude estimate) (%) - Sex: both sexes - Age group: 18+  years of age
# 0                                          17.805538
# 1                                          26.458910
# 2                                          23.822920
# 3                                          19.466227
# 4                                          11.380967

# %%
obesity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 4 columns):
#  #   Column                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                       --------------  -----
#  0   Entity                                                                                                       193 non-null    object
#  1   Code                                                                                                         193 non-null    object
#  2   Year                                                                                                         193 non-null    int64
#  3   Obesity among adults, BMI >= 30 kg/m2 (crude estimate) (%) - Sex: both sexes - Age group: 18+  years of age  193 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# ...

# %%
obesity.shape
# Out:
# (193, 4)

# %%
obesity.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Obesity among adults, BMI >= 30 kg/m2 (crude estimate) (%) - Sex: both sexes - Age group: 18+  years of age'],
#       dtype='object')

# %%
obesity.isnull().sum()
# Out:
# Entity                                                                                                         0
# Code                                                                                                           0
# Year                                                                                                           0
# Obesity among adults, BMI >= 30 kg/m2 (crude estimate) (%) - Sex: both sexes - Age group: 18+  years of age    0
# dtype: int64

# %%
obesity_clean = obesity.rename(columns={"Entity": "Country", "Code": "Country_Code", "Obesity among adults, BMI >= 30 kg/m2 (crude estimate) (%) - Sex: both sexes - Age group: 18+ years of age": "Obesity"})

# %%
obesity_clean = obesity_clean.drop(columns=["Year"])

# %%
obesity_clean.head()
# Out:
#        Country Country_Code  \
# 0  Afghanistan          AFG
# 1      Albania          ALB
# 2      Algeria          DZA
# 3      Andorra          AND
# 4       Angola          AGO
#
#    Obesity among adults, BMI >= 30 kg/m2 (crude estimate) (%) - Sex: both sexes - Age group: 18+  years of age
# 0                                          17.805538
# 1                                          26.458910
# 2                                          23.822920
# 3                                          19.466227
# 4                                          11.380967

# %%
obesity_clean.isnull().sum()
# Out:
# Country                                                                                                        0
# Country_Code                                                                                                   0
# Obesity among adults, BMI >= 30 kg/m2 (crude estimate) (%) - Sex: both sexes - Age group: 18+  years of age    0
# dtype: int64

# %%
obesity_clean.duplicated().sum()
# Out:
# 0

# %%
obesity_clean.to_csv(r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\processed\obesity_clean.csv", index=False)
