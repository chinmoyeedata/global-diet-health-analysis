# %% [markdown]
# # Diet and Health Analysis Project
#
# ## Notebook 2: Data Merging
#
# ### Merged all the cleaned dataset into one for analysis

# %%
import pandas as pd

# %%
food = pd.read_csv(r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\processed\food_clean.csv")

gdp = pd.read_csv(r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\processed\gdp_clean.csv")

life = pd.read_csv(r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\processed\life_expectancy_clean.csv")

diabetes = pd.read_csv(r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\processed\diabetes_clean.csv")

obesity = pd.read_csv(r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\processed\obesity_clean.csv")

# %%
food.shape
# Out:
# (1239, 5)

# %%
gdp.shape
# Out:
# (266, 3)

# %%
life.shape
# Out:
# (265, 3)

# %%
diabetes.shape
# Out:
# (257, 3)

# %%
obesity.shape
# Out:
# (193, 3)

# %%
food.head(10)
# Out:
#        Country                              Element            Food_Category  \
# 0  Afghanistan  Food supply quantity (kg/capita/yr)                     Eggs
# 1  Afghanistan  Food supply quantity (kg/capita/yr)            Fish, Seafood
# 2  Afghanistan  Food supply quantity (kg/capita/yr)  Fruits - Excluding Wine
# 3  Afghanistan  Food supply quantity (kg/capita/yr)                     Meat
# 4  Afghanistan  Food supply quantity (kg/capita/yr)  Milk - Excluding Butter
# 5  Afghanistan  Food supply quantity (kg/capita/yr)       Sugar & Sweeteners
# 6  Afghanistan  Food supply quantity (kg/capita/yr)               Vegetables
# 7      Albania  Food supply quantity (kg/capita/yr)                     Eggs
# 8      Albania  Food supply quantity (kg/capita/yr)            Fish, Seafood
# 9      Albania  Food supply quantity (kg/capita/yr)  Fruits - Excluding Wine
#
#      Unit   Value
# 0  kg/cap    0.58
# 1  kg/cap    0.38
# 2  kg/cap   39.92
# 3  kg/cap    6.39
# 4  kg/cap   37.11
# ...

# %%
food["Food_Category"].unique()
# Out:
# array(['Eggs', 'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat',
#        'Milk - Excluding Butter', 'Sugar & Sweeteners', 'Vegetables'],
#       dtype=object)

# %%
food["Food_Category"].nunique()
# Out:
# 7

# %%
food_pivot = food.pivot(index="Country", columns="Food_Category", values="Value").reset_index()

# %%
food_pivot.head()
# Out:
# Food_Category              Country   Eggs  Fish, Seafood  \
# 0                      Afghanistan   0.58           0.38
# 1                          Albania  11.62           8.60
# 2                          Algeria   6.05           2.75
# 3                           Angola   1.74          14.34
# 4              Antigua and Barbuda   6.02          54.52
#
# Food_Category  Fruits - Excluding Wine   Meat  Milk - Excluding Butter  \
# 0                                39.92   6.39                    37.11
# 1                               185.68  56.68                   290.98
# 2                               107.14  22.27                   145.25
# 3                                82.42  18.59                     7.82
# 4                               241.73  96.37                   117.21
#
# Food_Category  Sugar & Sweeteners  Vegetables
# 0                           10.60       63.41
# 1                           53.65      382.37
# 2                           31.07      221.33
# ...

# %%
food_pivot.columns.name = None

# %%
food_pivot.head()
# Out:
#                Country   Eggs  Fish, Seafood  Fruits - Excluding Wine   Meat  \
# 0          Afghanistan   0.58           0.38                    39.92   6.39
# 1              Albania  11.62           8.60                   185.68  56.68
# 2              Algeria   6.05           2.75                   107.14  22.27
# 3               Angola   1.74          14.34                    82.42  18.59
# 4  Antigua and Barbuda   6.02          54.52                   241.73  96.37
#
#    Milk - Excluding Butter  Sugar & Sweeteners  Vegetables
# 0                    37.11               10.60       63.41
# 1                   290.98               53.65      382.37
# 2                   145.25               31.07      221.33
# 3                     7.82               14.66       54.87
# 4                   117.21               47.98      101.09

# %%
food_pivot.shape
# Out:
# (177, 8)

# %%
food_pivot.isnull().sum()
# Out:
# Country                    0
# Eggs                       0
# Fish, Seafood              0
# Fruits - Excluding Wine    0
# Meat                       0
# Milk - Excluding Butter    0
# Sugar & Sweeteners         0
# Vegetables                 0
# dtype: int64

# %%
food_pivot.to_csv(r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\processed\food_pivot.csv", index=False)

# %%
food.columns
# Out:
# Index(['Country', 'Element', 'Food_Category', 'Unit', 'Value'], dtype='object')

# %%
gdp.columns
# Out:
# Index(['Country', 'Country_Code', 'GDP_per_Capita'], dtype='object')

# %%
life.columns
# Out:
# Index(['Country', 'Country_Code', 'Life_Expectancy'], dtype='object')

# %%
diabetes.columns
# Out:
# Index(['Country', 'Country_Code', 'Diabetes_Prevalence'], dtype='object')

# %%
obesity.columns
# Out:
# Index(['Country', 'Country_Code',
#        'Obesity among adults, BMI >= 30 kg/m2 (crude estimate) (%) - Sex: both sexes - Age group: 18+  years of age'],
#       dtype='object')

# %%
merged = pd.merge(food_pivot, gdp, on="Country", how="left")

# %%
merged.head()
# Out:
#                Country   Eggs  Fish, Seafood  Fruits - Excluding Wine   Meat  \
# 0          Afghanistan   0.58           0.38                    39.92   6.39
# 1              Albania  11.62           8.60                   185.68  56.68
# 2              Algeria   6.05           2.75                   107.14  22.27
# 3               Angola   1.74          14.34                    82.42  18.59
# 4  Antigua and Barbuda   6.02          54.52                   241.73  96.37
#
#    Milk - Excluding Butter  Sugar & Sweeteners  Vegetables Country_Code  \
# 0                    37.11               10.60       63.41          AFG
# 1                   290.98               53.65      382.37          ALB
# 2                   145.25               31.07      221.33          DZA
# 3                     7.82               14.66       54.87          AGO
# 4                   117.21               47.98      101.09          ATG
#
#    GDP_per_Capita
# 0      413.757895
# 1     9730.869219
# ...

# %%
merged = pd.merge(merged, life[["Country", "Life_Expectancy"]], on="Country", how="left")

# %%
merged = pd.merge(merged, diabetes[["Country", "Diabetes_Prevalence"]], on="Country", how="left")

# %%
merged.head()
# Out:
#                Country   Eggs  Fish, Seafood  Fruits - Excluding Wine   Meat  \
# 0          Afghanistan   0.58           0.38                    39.92   6.39
# 1              Albania  11.62           8.60                   185.68  56.68
# 2              Algeria   6.05           2.75                   107.14  22.27
# 3               Angola   1.74          14.34                    82.42  18.59
# 4  Antigua and Barbuda   6.02          54.52                   241.73  96.37
#
#    Milk - Excluding Butter  Sugar & Sweeteners  Vegetables Country_Code  \
# 0                    37.11               10.60       63.41          AFG
# 1                   290.98               53.65      382.37          ALB
# 2                   145.25               31.07      221.33          DZA
# 3                     7.82               14.66       54.87          AGO
# 4                   117.21               47.98      101.09          ATG
#
#    GDP_per_Capita  Life_Expectancy  Diabetes_Prevalence
# ...

# %%
obesity.columns = ["Country", "Country_Code", "Obesity"]

# %%
obesity.columns
# Out:
# Index(['Country', 'Country_Code', 'Obesity'], dtype='object')

# %%
merged = pd.merge(merged, obesity[["Country", "Obesity"]], on="Country", how="left")

# %%
merged.head()
# Out:
#                Country   Eggs  Fish, Seafood  Fruits - Excluding Wine   Meat  \
# 0          Afghanistan   0.58           0.38                    39.92   6.39
# 1              Albania  11.62           8.60                   185.68  56.68
# 2              Algeria   6.05           2.75                   107.14  22.27
# 3               Angola   1.74          14.34                    82.42  18.59
# 4  Antigua and Barbuda   6.02          54.52                   241.73  96.37
#
#    Milk - Excluding Butter  Sugar & Sweeteners  Vegetables Country_Code  \
# 0                    37.11               10.60       63.41          AFG
# 1                   290.98               53.65      382.37          ALB
# 2                   145.25               31.07      221.33          DZA
# 3                     7.82               14.66       54.87          AGO
# 4                   117.21               47.98      101.09          ATG
#
#    GDP_per_Capita  Life_Expectancy  Diabetes_Prevalence    Obesity
# ...

# %%
merged.tail()
# Out:
#                                 Country  Eggs  Fish, Seafood  \
# 172  Venezuela (Bolivarian Republic of)  6.94           8.75
# 173                            Viet Nam  3.96          40.06
# 174                               Yemen  1.60           2.02
# 175                              Zambia  2.70          12.89
# 176                            Zimbabwe  1.56           2.63
#
#      Fruits - Excluding Wine   Meat  Milk - Excluding Butter  \
# 172                    91.82  37.98                   124.63
# 173                    99.61  60.48                    37.38
# 174                    26.47  13.72                    32.80
# 175                     4.27  17.63                     8.10
# 176                    43.01  57.58                    27.22
#
#      Sugar & Sweeteners  Vegetables Country_Code  GDP_per_Capita  \
# 172               35.26       47.94          NaN             NaN
# 173               29.60      191.32          VNM     4323.350320
# ...

# %%
merged.shape
# Out:
# (177, 13)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  177 non-null    object
#  1   Eggs                     177 non-null    float64
#  2   Fish, Seafood            177 non-null    float64
#  3   Fruits - Excluding Wine  177 non-null    float64
#  4   Meat                     177 non-null    float64
#  5   Milk - Excluding Butter  177 non-null    float64
#  6   Sugar & Sweeteners       177 non-null    float64
#  7   Vegetables               177 non-null    float64
#  8   Country_Code             149 non-null    object
#  9   GDP_per_Capita           148 non-null    float64
#  10  Life_Expectancy          149 non-null    float64
#  11  Diabetes_Prevalence      149 non-null    float64
#  12  Obesity                  152 non-null    float64
# dtypes: float64(11), object(2)
# ...

# %%
merged.isnull().sum()
# Out:
# Country                     0
# Eggs                        0
# Fish, Seafood               0
# Fruits - Excluding Wine     0
# Meat                        0
# Milk - Excluding Butter     0
# Sugar & Sweeteners          0
# Vegetables                  0
# Country_Code               28
# GDP_per_Capita             29
# Life_Expectancy            28
# Diabetes_Prevalence        28
# Obesity                    25
# dtype: int64

# %%
merged.duplicated().sum()
# Out:
# 0

# %%
merged[merged["GDP_per_Capita"].isnull()]["Country"]
# Out:
# 10                                               Bahamas
# 18                      Bolivia (Plurinational State of)
# 30                                  China, Hong Kong SAR
# 31                                      China, Macao SAR
# 32                             China, Taiwan Province of
# 33                                       China, mainland
# 36                                                 Congo
# 41                                         Côte d'Ivoire
# 42                      Democratic Republic of the Congo
# 47                                                 Egypt
# 57                                                Gambia
# 73                            Iran (Islamic Republic of)
# 84                                            Kyrgyzstan
# 85                      Lao People's Democratic Republic
# 102                     Micronesia (Federated States of)
# 111                         Netherlands (Kingdom of the)
# ...

# %%
merged[merged["Life_Expectancy"].isnull()]["Country"]
# Out:
# 10                                               Bahamas
# 18                      Bolivia (Plurinational State of)
# 30                                  China, Hong Kong SAR
# 31                                      China, Macao SAR
# 32                             China, Taiwan Province of
# 33                                       China, mainland
# 36                                                 Congo
# 41                                         Côte d'Ivoire
# 42                      Democratic Republic of the Congo
# 47                                                 Egypt
# 57                                                Gambia
# 73                            Iran (Islamic Republic of)
# 84                                            Kyrgyzstan
# 85                      Lao People's Democratic Republic
# 102                     Micronesia (Federated States of)
# 111                         Netherlands (Kingdom of the)
# ...

# %%
merged[merged["Diabetes_Prevalence"].isnull()]["Country"]
# Out:
# 10                                               Bahamas
# 18                      Bolivia (Plurinational State of)
# 30                                  China, Hong Kong SAR
# 31                                      China, Macao SAR
# 32                             China, Taiwan Province of
# 33                                       China, mainland
# 36                                                 Congo
# 41                                         Côte d'Ivoire
# 42                      Democratic Republic of the Congo
# 47                                                 Egypt
# 57                                                Gambia
# 73                            Iran (Islamic Republic of)
# 84                                            Kyrgyzstan
# 85                      Lao People's Democratic Republic
# 102                     Micronesia (Federated States of)
# 111                         Netherlands (Kingdom of the)
# ...

# %%
merged[merged["Diabetes_Prevalence"].isnull()]["Country"]
# Out:
# 10                                               Bahamas
# 18                      Bolivia (Plurinational State of)
# 30                                  China, Hong Kong SAR
# 31                                      China, Macao SAR
# 32                             China, Taiwan Province of
# 33                                       China, mainland
# 36                                                 Congo
# 41                                         Côte d'Ivoire
# 42                      Democratic Republic of the Congo
# 47                                                 Egypt
# 57                                                Gambia
# 73                            Iran (Islamic Republic of)
# 84                                            Kyrgyzstan
# 85                      Lao People's Democratic Republic
# 102                     Micronesia (Federated States of)
# 111                         Netherlands (Kingdom of the)
# ...

# %%
merged[merged["Obesity"].isnull()]["Country"]
# Out:
# 18                      Bolivia (Plurinational State of)
# 24                                            Cabo Verde
# 30                                  China, Hong Kong SAR
# 31                                      China, Macao SAR
# 32                             China, Taiwan Province of
# 33                                       China, mainland
# 41                                         Côte d'Ivoire
# 42                      Democratic Republic of the Congo
# 55                                      French Polynesia
# 73                            Iran (Islamic Republic of)
# 85                      Lao People's Democratic Republic
# 102                     Micronesia (Federated States of)
# 111                         Netherlands (Kingdom of the)
# 112                                        New Caledonia
# 129                                    Republic of Korea
# 130                                  Republic of Moldova
# ...

# %%
merged.shape
# Out:
# (177, 13)

# %%
merged.isnull().sum()
# Out:
# Country                     0
# Eggs                        0
# Fish, Seafood               0
# Fruits - Excluding Wine     0
# Meat                        0
# Milk - Excluding Butter     0
# Sugar & Sweeteners          0
# Vegetables                  0
# Country_Code               28
# GDP_per_Capita             29
# Life_Expectancy            28
# Diabetes_Prevalence        28
# Obesity                    25
# dtype: int64

# %%
country_lookup = gdp[["Country", "Country_Code"]]

# %%
food_code = pd.merge(food_pivot, country_lookup, on="Country", how="left")

# %%
food_code.head()
# Out:
#                Country   Eggs  Fish, Seafood  Fruits - Excluding Wine   Meat  \
# 0          Afghanistan   0.58           0.38                    39.92   6.39
# 1              Albania  11.62           8.60                   185.68  56.68
# 2              Algeria   6.05           2.75                   107.14  22.27
# 3               Angola   1.74          14.34                    82.42  18.59
# 4  Antigua and Barbuda   6.02          54.52                   241.73  96.37
#
#    Milk - Excluding Butter  Sugar & Sweeteners  Vegetables Country_Code
# 0                    37.11               10.60       63.41          AFG
# 1                   290.98               53.65      382.37          ALB
# 2                   145.25               31.07      221.33          DZA
# 3                     7.82               14.66       54.87          AGO
# 4                   117.21               47.98      101.09          ATG

# %%
food_code[food_code["Country_Code"].isnull()]["Country"]
# Out:
# 10                                               Bahamas
# 18                      Bolivia (Plurinational State of)
# 30                                  China, Hong Kong SAR
# 31                                      China, Macao SAR
# 32                             China, Taiwan Province of
# 33                                       China, mainland
# 36                                                 Congo
# 41                                         Côte d'Ivoire
# 42                      Democratic Republic of the Congo
# 47                                                 Egypt
# 57                                                Gambia
# 73                            Iran (Islamic Republic of)
# 84                                            Kyrgyzstan
# 85                      Lao People's Democratic Republic
# 102                     Micronesia (Federated States of)
# 111                         Netherlands (Kingdom of the)
# ...

# %%
gdp[gdp["Country"].str.contains("Bah", case=False, na=False)]
# Out:
#          Country Country_Code  GDP_per_Capita
# 22       Bahrain          BHR    29290.128422
# 23  Bahamas, The          BHS    38231.774484

# %%
gdp[gdp["Country"].str.contains("Bolivia", case=False, na=False)]
# Out:
#     Country Country_Code  GDP_per_Capita
# 28  Bolivia          BOL     4274.708205

# %%
gdp[gdp["Country"].str.contains("Hong", case=False, na=False)]
# Out:
#                  Country Country_Code  GDP_per_Capita
# 96  Hong Kong SAR, China          HKG    50562.363314

# %%
gdp[gdp["Country"].str.contains("Macao", case=False, na=False)]
# Out:
#               Country Country_Code  GDP_per_Capita
# 146  Macao SAR, China          MAC    67216.363111

# %%
gdp[gdp["Country"].str.contains("Taiwan", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [Country, Country_Code, GDP_per_Capita]
# Index: []

# %%
gdp[gdp["Country"].str.contains("Congo", case=False, na=False)]
# Out:
#              Country Country_Code  GDP_per_Capita
# 43  Congo, Dem. Rep.          COD      660.212052
# 44       Congo, Rep.          COG     2477.978455

# %%
gdp[gdp["Country"].str.contains("Egypt", case=False, na=False)]
# Out:
#              Country Country_Code  GDP_per_Capita
# 67  Egypt, Arab Rep.          EGY     3456.789685

# %%
gdp[gdp["Country"].str.contains("Iran", case=False, na=False)]
# Out:
#                 Country Country_Code  GDP_per_Capita
# 112  Iran, Islamic Rep.          IRN     5049.299316

# %%
gdp[gdp["Country"].str.contains("Korea", case=False, na=False)]
# Out:
#                        Country Country_Code  GDP_per_Capita
# 126                Korea, Rep.          KOR    35674.095996
# 193  Korea, Dem. People's Rep.          PRK             NaN

# %%
gdp[gdp["Country"].str.contains("United", case=False, na=False)]
# Out:
#                   Country Country_Code  GDP_per_Capita
# 8    United Arab Emirates          ARE    49850.687218
# 81         United Kingdom          GBR    49944.470212
# 251         United States          USA    81032.262118

# %%
gdp[gdp["Country"].str.contains("Turkey", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [Country, Country_Code, GDP_per_Capita]
# Index: []

# %%
gdp[gdp["Country"].str.contains("Vene", case=False, na=False)]
# Out:
#            Country Country_Code  GDP_per_Capita
# 254  Venezuela, RB          VEN     3617.435946

# %%
food_code = pd.merge(food_pivot, country_lookup, on="Country", how="left")

# %%
food_code["Country"] = food_code["Country"].replace({"Bahamas": "Bahamas, The", "Bolivia (Plurinational State of)": "Bolivia",
"China, Hong Kong SAR": "Hong Kong SAR, China", "China, Macao SAR": "Macao SAR, China", "Democratic Republic of the Congo": "Congo, Dem. Rep.",
"Congo": "Congo, Rep.", "Egypt": "Egypt, Arab Rep.", "Iran (Islamic Republic of)": "Iran, Islamic Rep.", "Republic of Korea": "Korea, Rep.",
"United Kingdom of Great Britain and Northern Ireland": "United Kingdom", "United States of America": "United States", "Venezuela (Bolivarian Republic of)": "Venezuela, RB"
})

# %%
food_code = pd.merge(food_code, country_lookup, on="Country", how="left")

# %%
food_code.columns
# Out:
# Index(['Country', 'Eggs', 'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat',
#        'Milk - Excluding Butter', 'Sugar & Sweeteners', 'Vegetables',
#        'Country_Code_x', 'Country_Code_y'],
#       dtype='object')

# %%
food_code["Country_Code"] = food_code["Country_Code_x"].fillna(food_code["Country_Code_y"])

# %%
food_code.drop(columns=["Country_Code_x", "Country_Code_y"], inplace=True)

# %%
food_code[food_code["Country_Code"].isnull()]["Country"]
# Out:
# 32            China, Taiwan Province of
# 33                      China, mainland
# 41                        Côte d'Ivoire
# 57                               Gambia
# 84                           Kyrgyzstan
# 85     Lao People's Democratic Republic
# 102    Micronesia (Federated States of)
# 111        Netherlands (Kingdom of the)
# 130                 Republic of Moldova
# 134               Saint Kitts and Nevis
# 135                         Saint Lucia
# 136    Saint Vincent and the Grenadines
# 144                            Slovakia
# 162                             Türkiye
# 167         United Republic of Tanzania
# 174                               Yemen
# Name: Country, dtype: object

# %%
gdp[gdp["Country"].str.contains("Taiwan", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [Country, Country_Code, GDP_per_Capita]
# Index: []

# %%
gdp[gdp["Country"].str.contains("China", case=False, na=False)]
# Out:
#                   Country Country_Code  GDP_per_Capita
# 40                  China          CHN    12951.178240
# 96   Hong Kong SAR, China          HKG    50562.363314
# 146      Macao SAR, China          MAC    67216.363111

# %%
gdp[gdp["Country"].str.contains("Ivoire", case=False, na=False)]
# Out:
#           Country Country_Code  GDP_per_Capita
# 41  Cote d'Ivoire          CIV     2591.965905

# %%
gdp[gdp["Country"].str.contains("Gambia", case=False, na=False)]
# Out:
#         Country Country_Code  GDP_per_Capita
# 86  Gambia, The          GMB      883.024112

# %%
gdp[gdp["Country"].str.contains("Kyrgyz", case=False, na=False)]
# Out:
#              Country Country_Code  GDP_per_Capita
# 122  Kyrgyz Republic          KGZ     2138.222102

# %%
gdp[gdp["Country"].str.contains("Lao", case=False, na=False)]
# Out:
#      Country Country_Code  GDP_per_Capita
# 129  Lao PDR          LAO     2066.949798

# %%
gdp[gdp["Country"].str.contains("Micronesia", case=False, na=False)]
# Out:
#                   Country Country_Code  GDP_per_Capita
# 79  Micronesia, Fed. Sts.          FSM     3919.643079

# %%
gdp[gdp["Country"].str.contains("Netherlands", case=False, na=False)]
# Out:
#          Country Country_Code  GDP_per_Capita
# 176  Netherlands          NLD    63515.603078

# %%
gdp[gdp["Country"].str.contains("Moldova", case=False, na=False)]
# Out:
#      Country Country_Code  GDP_per_Capita
# 150  Moldova          MDA     6799.585946

# %%
gdp[gdp["Country"].str.contains("Saint", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [Country, Country_Code, GDP_per_Capita]
# Index: []

# %%
gdp[gdp["Country"].str.contains("Slovak", case=False, na=False)]
# Out:
#              Country Country_Code  GDP_per_Capita
# 221  Slovak Republic          SVK    24614.873464

# %%
gdp[gdp["Country"].str.contains("Turk", case=False, na=False)]
# Out:
#                       Country Country_Code  GDP_per_Capita
# 228  Turks and Caicos Islands          TCA    35470.215161
# 235              Turkmenistan          TKM     6231.913238
# 244                   Turkiye          TUR    13375.094728

# %%
gdp[gdp["Country"].str.contains("Tanzania", case=False, na=False)]
# Out:
#       Country Country_Code  GDP_per_Capita
# 246  Tanzania          TZA     1224.002197

# %%
gdp[gdp["Country"].str.contains("Yemen", case=False, na=False)]
# Out:
#          Country Country_Code  GDP_per_Capita
# 262  Yemen, Rep.          YEM             NaN

# %%
food_code["Country"] = food_code["Country"].replace({
    "China, Taiwan Province of": "Taiwan, China",
    "China, mainland": "China",
    "Côte d'Ivoire": "Cote d'Ivoire",
    "Gambia": "Gambia, The",
    "Kyrgyzstan": "Kyrgyz Republic",
    "Lao People's Democratic Republic": "Lao PDR",
    "Micronesia (Federated States of)": "Micronesia, Fed. Sts.",
    "Netherlands (Kingdom of the)": "Netherlands",
    "Republic of Moldova": "Moldova",
    "Slovakia": "Slovak Republic",
    "Türkiye": "Turkiye",
    "United Republic of Tanzania": "Tanzania",
    "Yemen": "Yemen, Rep."
})

# %%
gdp[gdp["Country"].str.contains("Kitts", case=False, na=False)]
# Out:
#                  Country Country_Code  GDP_per_Capita
# 125  St. Kitts and Nevis          KNA    22576.924844

# %%
gdp[gdp["Country"].str.contains("Vincent", case=False, na=False)]
# Out:
#                             Country Country_Code  GDP_per_Capita
# 253  St. Vincent and the Grenadines          VCT    10582.365673

# %%
food_code = pd.merge(food_code.drop(columns="Country_Code"),
                     country_lookup,
                     on="Country",
                     how="left")

# %%
food_code[food_code["Country_Code"].isnull()]["Country"]
# Out:
# 32                        Taiwan, China
# 134               Saint Kitts and Nevis
# 135                         Saint Lucia
# 136    Saint Vincent and the Grenadines
# Name: Country, dtype: object

# %%
country_lookup[country_lookup["Country"].str.contains("Taiwan", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [Country, Country_Code]
# Index: []

# %%
country_lookup[country_lookup["Country"].str.contains("Lucia", case=False, na=False)]
# Out:
#        Country Country_Code
# 133  St. Lucia          LCA

# %%
country_lookup[country_lookup["Country"].str.contains("Kitts", case=False, na=False)]
# Out:
#                  Country Country_Code
# 125  St. Kitts and Nevis          KNA

# %%
country_lookup[country_lookup["Country"].str.contains("Vincent", case=False, na=False)]
# Out:
#                             Country Country_Code
# 253  St. Vincent and the Grenadines          VCT

# %%
food_code["Country"] = food_code["Country"].replace({
    "Saint Lucia": "St. Lucia",
    "Saint Kitts and Nevis": "St. Kitts and Nevis",
    "Saint Vincent and the Grenadines": "St. Vincent and the Grenadines"
})

# %%
food_code = pd.merge(
    food_code.drop(columns="Country_Code"),
    country_lookup,
    on="Country",
    how="left"
)

# %%
food_code[food_code["Country_Code"].isnull()]["Country"]
# Out:
# 32    Taiwan, China
# Name: Country, dtype: object

# %%
food_code = food_code.drop(
    food_code[food_code["Country"] == "Taiwan, China"].index
)

# %%
food_code[food_code["Country_Code"].isnull()]["Country"]
# Out:
# Series([], Name: Country, dtype: object)

# %%
food_code.shape
# Out:
# (176, 9)

# %%
food_code.to_csv(r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\processed\food_code.csv", index=False)

# %%
merged = pd.merge(food_code, gdp, on=["Country", "Country_Code"], how="left")

# %%
merged.shape
# Out:
# (176, 10)

# %%
merged.isnull().sum()
# Out:
# Country                    0
# Eggs                       0
# Fish, Seafood              0
# Fruits - Excluding Wine    0
# Meat                       0
# Milk - Excluding Butter    0
# Sugar & Sweeteners         0
# Vegetables                 0
# Country_Code               0
# GDP_per_Capita             2
# dtype: int64

# %%
merged[merged["GDP_per_Capita"].isnull()][["Country", "Country_Code"]]
# Out:
#                   Country Country_Code
# 152  Syrian Arab Republic          SYR
# 173           Yemen, Rep.          YEM

# %%
gdp[gdp["Country_Code"] == "SYR"]
# Out:
#                   Country Country_Code  GDP_per_Capita
# 227  Syrian Arab Republic          SYR             NaN

# %%
gdp[gdp["Country_Code"]=="YEM"]
# Out:
#          Country Country_Code  GDP_per_Capita
# 262  Yemen, Rep.          YEM             NaN

# %%
merged = pd.merge(
    merged,
    life,
    on=["Country", "Country_Code"],
    how="left"
)

# %%
merged.shape
# Out:
# (176, 11)

# %%
merged.isnull().sum()
# Out:
# Country                    0
# Eggs                       0
# Fish, Seafood              0
# Fruits - Excluding Wine    0
# Meat                       0
# Milk - Excluding Butter    0
# Sugar & Sweeteners         0
# Vegetables                 0
# Country_Code               0
# GDP_per_Capita             2
# Life_Expectancy            0
# dtype: int64

# %%
merged = pd.merge(
    merged,
    diabetes,
    on=["Country", "Country_Code"],
    how="left"
)

# %%
merged.shape
# Out:
# (176, 12)

# %%
merged.isnull().sum()
# Out:
# Country                    0
# Eggs                       0
# Fish, Seafood              0
# Fruits - Excluding Wine    0
# Meat                       0
# Milk - Excluding Butter    0
# Sugar & Sweeteners         0
# Vegetables                 0
# Country_Code               0
# GDP_per_Capita             2
# Life_Expectancy            0
# Diabetes_Prevalence        0
# dtype: int64

# %%
merged = pd.merge(
    merged,
    obesity,
    on=["Country", "Country_Code"],
    how="left"
)

# %%
merged.shape
# Out:
# (176, 13)

# %%
merged.isnull().sum()
# Out:
# Country                     0
# Eggs                        0
# Fish, Seafood               0
# Fruits - Excluding Wine     0
# Meat                        0
# Milk - Excluding Butter     0
# Sugar & Sweeteners          0
# Vegetables                  0
# Country_Code                0
# GDP_per_Capita              2
# Life_Expectancy             0
# Diabetes_Prevalence         0
# Obesity                    26
# dtype: int64

# %%
merged[merged["Obesity"].isnull()][["Country", "Country_Code"]]
# Out:
#                             Country Country_Code
# 10                     Bahamas, The          BHS
# 24                       Cabo Verde          CPV
# 30             Hong Kong SAR, China          HKG
# 31                 Macao SAR, China          MAC
# 35                      Congo, Rep.          COG
# 41                 Congo, Dem. Rep.          COD
# 46                 Egypt, Arab Rep.          EGY
# 54                 French Polynesia          PYF
# 56                      Gambia, The          GMB
# 72               Iran, Islamic Rep.          IRN
# 83                  Kyrgyz Republic          KGZ
# 84                          Lao PDR          LAO
# 101           Micronesia, Fed. Sts.          FSM
# 111                   New Caledonia          NCL
# 128                     Korea, Rep.          KOR
# 131              Russian Federation          RUS
# 133             St. Kitts and Nevis          KNA
# 134                       St. Lucia          LCA
# ...

# %%
merged = pd.merge(merged, obesity[["Country_Code", "Obesity"]], on="Country_Code", how="left")

# %%
merged.isnull().sum()
# Out:
# Country                     0
# Eggs                        0
# Fish, Seafood               0
# Fruits - Excluding Wine     0
# Meat                        0
# Milk - Excluding Butter     0
# Sugar & Sweeteners          0
# Vegetables                  0
# Country_Code                0
# GDP_per_Capita              2
# Life_Expectancy             0
# Diabetes_Prevalence         0
# Obesity_x                  26
# Obesity_y                   4
# dtype: int64

# %%
merged.drop(columns="Obesity_x", inplace=True)

# %%
merged.rename(columns={"Obesity_y": "Obesity"}, inplace=True)

# %%
merged.isnull().sum()
# Out:
# Country                    0
# Eggs                       0
# Fish, Seafood              0
# Fruits - Excluding Wine    0
# Meat                       0
# Milk - Excluding Butter    0
# Sugar & Sweeteners         0
# Vegetables                 0
# Country_Code               0
# GDP_per_Capita             2
# Life_Expectancy            0
# Diabetes_Prevalence        0
# Obesity                    4
# dtype: int64

# %%
merged.to_csv(r"C:\Users\Chinmoyee Bhuyan\OneDrive\Desktop\diet-health-analysis project\data\processed\merged_data.csv", index=False)
